# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os

os.getcwd()
# Out:
# '/content'

# %%
os.chdir('drive/MyDrive/-1000 to 1000')

# %%
# !pip install cobra
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 7.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.9/75.9 kB 10.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 142.0/142.0 kB 7.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.0/8.0 MB 21.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.4/116.4 kB 14.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 36.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.9/76.9 kB 8.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 7.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 526.7/526.7 kB 43.5 MB/s eta 0:00:00
# ...

# %%
# !python -m pip install gurobipy
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.4/13.4 MB 24.7 MB/s eta 0:00:00
# ...

# %%
# !tar xvfz "gurobi11.0.0_linux64.tar.gz"
# Out:
# gurobi1100/
# gurobi1100/linux64/
# gurobi1100/linux64/lib/
# gurobi1100/linux64/lib/gurobi.jar
# gurobi1100/linux64/lib/gurobi-javadoc.jar
# gurobi1100/linux64/lib/gurobi110.netstandard20.dll
# gurobi1100/linux64/lib/gurobi110.netstandard20.xml
# gurobi1100/linux64/lib/libgurobi.so.11.0.0
# gurobi1100/linux64/lib/libgurobi110_light.so
# gurobi1100/linux64/lib/libGurobiJni110.so
# gurobi1100/linux64/lib/libgurobi_g++8.5.a
# gurobi1100/linux64/lib/rootcert.pem
# gurobi1100/linux64/lib/python3.11/
# gurobi1100/linux64/lib/python3.11/gurobipy/
# gurobi1100/linux64/lib/python3.11/gurobipy/__init__.py
# gurobi1100/linux64/lib/python3.11/gurobipy/gurobipy.so
# gurobi1100/linux64/lib/python3.11/encodings/
# gurobi1100/linux64/lib/python3.11/encodings/aliases.py
# gurobi1100/linux64/lib/python3.11/encodings/ascii.py
# gurobi1100/linux64/lib/python3.11/encodings/base64_codec.py
# gurobi1100/linux64/lib/python3.11/encodings/big5hkscs.py
# gurobi1100/linux64/lib/python3.11/encodings/big5.py
# ...

# %%
# !tar -xzvf "licensetools11.0.0_linux64.tar.gz"

import gzip
f=gzip.open('licensetools11.0.0_linux64.tar.gz','rb')
file_content=f.read()
print(file_content)
# Out:
# grbprobe
# grb_ts
# grbgetkey
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
# !/opt/gurobi1100/linux64/bin/grbgetkey e004ae46-c1de-11ed-8dbe-0242ac190002
# Out:
# /bin/bash: line 1: /opt/gurobi1100/linux64/bin/grbgetkey: No such file or directory

# %%
# !grbgetkey e004ae46-c1de-11ed-8dbe-0242ac190002
# Out:
# /bin/bash: line 1: grbgetkey: command not found

# %%
import numpy as np
import pandas as pd

import os

from os.path import join

from time import time


from cobra.flux_analysis import (
    single_gene_deletion, single_reaction_deletion, double_gene_deletion,
    double_reaction_deletion)

import cobra

a = cobra.io.read_sbml_model("iEC1344_C.xml")
# Out:
# Restricted license - for non-production use only - expires 2025-11-24

# %%
cobra_config = cobra.Configuration()
cobra_config.solver = "gurobi"
cobra_config.solver
# Out:
# <module 'optlang.gurobi_interface' from '/usr/local/lib/python3.10/dist-packages/optlang/gurobi_interface.py'>

# %%
i3= int(((len(csvFile)-1)/2)+1)

# %%
int_reactions= list()
i= -1
n= 0
r = a.reactions[0]
r_id = r.id
non_zero= list()

for r in a.reactions:  #finds reactions that have one feasible value at flux=0 or for another flux
    i= i+1
    r = a.reactions[i]
    r_id = r.id

    csvFile = pd.read_csv('biomass_per_flux_for_reaction_{}.csv'.format(r_id))
    v= len(csvFile["Biomass"])-csvFile["Biomass"].isna().sum()
    n= int((len(csvFile)-1)/2)

    flt= float(csvFile.iloc[n,  2])

    if csvFile.iloc[n,  2] != 0 and csvFile.iloc[n,  2] == flt:
      non_zero.append(r_id)

non_zero
# Out:
# ['EX_cm_e',
#  'EX_cmp_e',
#  'EX_co2_e',
#  'EX_colipa_e',
#  'EX_colipap_e',
#  'EX_cpgn_e',
#  'EX_cpgn_un_e',
#  'EX_crn_e',
#  'EX_crn__D_e',
#  'EX_csn_e',
#  'EX_glcn_e',
#  'EX_cu_e',
#  'EX_glcr_e',
#  'DM_4crsol_c',
#  'EX_glcur_e',
#  'EX_glcur1p_e',
#  'EX_gln__L_e',
#  'EX_glu__L_e',
#  'EX_cyan_e',
#  'DM_aacald_c',
#  'DM_mththf_c',
#  'DM_oxam_c',
#  'EX_gly_e',
#  'EX_glyald_e',
#  'EX_glyb_e',
#  'EX_glyc_e',
#  'EX_glyc__R_e',
#  'EX_glyc2p_e',
#  'EX_glyc3p_e',
#  'EX_glyclt_e',
#  'EX_gmp_e',
#  'EX_gsn_e',
#  'EX_gthox_e',
#  'EX_gthrd_e',
#  'EX_gtp_e',
#  'EX_gua_e',
#  'EX_h_e',
#  'EX_h2_e',
#  'EX_h2o_e',
#  'BIOMASS_Ec_iJO1366_WT_53p95M',
#  'EX_12ppd__R_e',
#  'EX_12ppd__S_e',
#  'EX_14glucan_e',
#  'EX_15dap_e',
#  'EX_23camp_e',
#  'EX_23ccmp_e',
#  'EX_23cgmp_e',
#  'EX_23cump_e',
#  'EX_23dappa_e',
#  'EX_26dap__M_e',
#  'EX_2ddglcn_e',
#  'EX_h2o2_e',
#  'EX_h2s_e',
#  'EX_hacolipa_e',
#  'EX_halipa_e',
#  'EX_hdca_e',
#  'EX_34dhpac_e',
# ...

# %%
len(non_zero)
# Out:
# 2442
